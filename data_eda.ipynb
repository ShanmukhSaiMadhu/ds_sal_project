# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir(r'D:\DA\Projects\Data Science Salary Prediction\ds_sal_project')
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'at_headquarter', 'age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'

def seniority(title):
    if 'sr' in title.lower() or 'snr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jnr' in title.lower() or 'junior' in title.lower():
        return 'jr'
    else:
        return 'na'

## Job title and seniority

## Fix state Los Angles

## Job description length

## Competitor count

## Hourly wage to anual

## remove new line from company text

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# job_simp
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: count, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# seniority
# na        519
# senior    220
# jr          3
# Name: count, dtype: int64

# %%
## Fix state Los Angles

df.state = df.state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.state.value_counts()
# Out:
# state
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: count, dtype: int64

# %%
## Job description length

df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df.desc_len
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: Job Description, Length: 742, dtype: int64

# %%
## Competitor count

df['num_comp'] = df.Competitors.apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df.num_comp
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: num_comp, Length: 742, dtype: int64

# %%
df.Competitors
# Out:
# 0                                                     -1
# 1                                                     -1
# 2                                                     -1
# 3      Oak Ridge National Laboratory, National Renewa...
# 4                   Commerce Signals, Cardlytics, Yodlee
#                              ...
# 737                           Pfizer, AstraZeneca, Merck
# 738                      See Tickets, TicketWeb, Vendini
# 739                                                   -1
# 740                                                   -1
# 741                                                   -1
# Name: Competitors, Length: 742, dtype: object

# %%
## Hourly wage to anual

df['min_salary'] = df.apply(lambda x: x.min_salary * 2 if x.hourly == 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary * 2 if x.hourly == 1 else x.max_salary, axis = 1)

# %%
df[df.hourly == 1][['min_salary', 'max_salary']]
# Out:
#      min_salary  max_salary
# 165          34          48
# 177          42          68
# 197          36          50
# 202          42          68
# 210          30          50
# 246          34          48
# 271          42          68
# 337          36          50
# 345          48          78
# 357          42          68
# 363          50          56
# 408          42          58
# 409          20          34
# 492          36          50
# 509          48          78
# 533          42          68
# 542          50          56
# 617          42          58
# 618          20          34
# 645          54          94
# 666          36          50
# 682          48          78
# 711          42          68
# 724          50          56

# %%
## remove new line from company text

df.company_text = df.company_text.apply(lambda x: x.replace('\n', ''))

# %%
df.company_text
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_text, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employee_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  at_headquarter         age   python_yn  \
# count  742.000000  742.000000      742.000000  742.000000  742.000000
# mean   128.149596  100.626011        0.557951   50.322102    0.528302
# std     45.220324   38.855948        0.496965   54.026459    0.499535
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'at_headquarter', 'age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'num_comp',
#        'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age.hist()
# Out:
# <Axes: >

# %%
df.desc_len.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column = ['age', 'avg_salary', 'Rating'])
# Out:
# <Axes: >

# %%
df.boxplot(column = 'Rating')
# Out:
# <Axes: >

# %%
corr = df[['age', 'avg_salary', 'Rating', 'desc_len','num_comp']].corr()

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'at_headquarter', 'age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'num_comp',
#        'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_text', 'state', 'at_headquarter', 'python_yn', 'R_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("Graph for %s: total = %d" % (i, len(cat_num)))
    sns.barplot(x=cat_num.index, y=cat_num).tick_params(axis='x', rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 200
# Graph for Headquarters: total = 198
# Graph for Size: total = 9
# Graph for Type of ownership: total = 11
# Graph for Industry: total = 60
# Graph for Sector: total = 25
# Graph for Revenue: total = 14
# Graph for company_text: total = 343
# Graph for state: total = 37
# Graph for at_headquarter: total = 2
# Graph for python_yn: total = 2
# Graph for R_yn: total = 2
# Graph for spark_yn: total = 2
# Graph for aws_yn: total = 2
# Graph for excel_yn: total = 2
# Graph for job_simp: total = 7
# Graph for seniority: total = 3

# %%
df.at_headquarter
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 737    0
# 738    0
# 739    1
# 740    0
# 741    0
# Name: at_headquarter, Length: 742, dtype: int64

# %%
df.at_headquarter.value_counts()
# Out:
# at_headquarter
# 1    414
# 0    328
# Name: count, dtype: int64

# %%
for i in df_cat[['Location', 'Headquarters', 'company_text']].columns:
    cat_num = df_cat[i].value_counts()[:20] #Top 20 
    print("Graph for %s: total = %d" % (i, len(cat_num)))
    sns.barplot(x=cat_num.index, y=cat_num).tick_params(axis='x', rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 20
# Graph for Headquarters: total = 20
# Graph for company_text: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'at_headquarter', 'age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'num_comp',
#        'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          53.250000
#                na          61.308219
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

pd.pivot_table(df, index = ['state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('state', ascending = False)
# Out:
#                       avg_salary
# state job_simp
# WI    na                       4
#       data scientist           3
#       analyst                  3
# WA    na                       1
#       data scientist          17
#       analyst                  3
# VA    na                       5
#       mle                      2
#       data scientist          18
#       data engineer           10
#       analyst                  6
# UT    data engineer            3
#       analyst                  4
#       data scientist           3
# TX    na                       7
#       data scientist          13
#       data engineer            8
# TN    data scientist           1
#       data engineer           10
#       analyst                  2
# SC    na                       1
# RI    analyst                  1
# PA    manager                  3
#       data engineer            1
#       data scientist           6
#       analyst                  8
#       mle                      7
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#        avg_salary
# state
# DC     149.000000
# CA     142.522059
# UT     140.500000
# MO     127.666667
# IL     117.233333
# NC     117.000000
# NY     115.250000
# MA     113.750000
# WI     113.500000
# PA     113.333333
# MD     109.115385
# CO     108.666667
# VA     108.416667
# NJ     106.875000
# MI     106.625000
# OH     105.285714
# TX     100.730769
# WA      99.764706
# OR      98.500000
# FL      97.357143
# TN      96.000000
# IN      84.500000
# KY      84.000000
# CT      84.000000
# GA      81.333333
# NM      74.333333
# AZ      69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employee_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'state', 'at_headquarter', 'age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'job_simp', 'seniority', 'num_comp',
#        'desc_len'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employee_provided', 'python_yn', 'R_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values('avg_salary', ascending =False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Sector', columns = 'python_yn', values= 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                              0      1
# Sector
# -1                                   8.0    2.0
# Accounting & Legal                   NaN    1.0
# Aerospace & Defense                  5.0   20.0
# Agriculture & Forestry               1.0    NaN
# Arts, Entertainment & Recreation     4.0    NaN
# Biotech & Pharmaceuticals           74.0   38.0
# Business Services                   34.0   63.0
# Construction, Repair & Maintenance   3.0    NaN
# Consumer Services                    NaN    4.0
# Education                            9.0   14.0
# Finance                             18.0   24.0
# Government                           4.0    7.0
# Health Care                         39.0   10.0
# Information Technology              58.0  122.0
# Insurance                           30.0   39.0
# Manufacturing                       29.0    5.0
# Media                                1.0    5.0
# Mining & Metals                      NaN    3.0
# ...

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
